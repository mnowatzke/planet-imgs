# %%
import os
import errno
import datetime
import time
from zipfile import ZipFile
import json
from pathlib import Path
import tomli
import geopandas as gpd
import shapely
import requests
import rasterio as rio
from requests.auth import HTTPBasicAuth
import matplotlib.pyplot as plt
import numpy as np
import glob
# from geojson import Polygon, Feature, FeatureCollection

# %%
# sievers_bound = gpd.read_file('data/sievers_bound.geojson')
# cas_bound = gpd.read_file('data/sievers_bound.geojson')
# accola_bound = gpd.read_file('data/sievers_bound.geojson')
# mud_bound = gpd.read_file('data/mud_creek_watershed_4326.geojson')

# %%
# from distutils.command.config import config
class PlanetConfig:
    def __init__(self, config_file="config.toml"):
        self.config_file = config_file
        # self.order_url = 'https://api.planet.com/compute/ops/orders/v2'
        self.headers = {'content-type': 'application/json'}
        
        try:
            with open(config_file, "rb") as f:
                self.config = tomli.load(f)
        except EnvironmentError as e:
            print(os.strerror(e.errno))
            print("Missing configiguration file.")
            print("Please create a config.toml file with your Planet API key.")
            print("Use config.toml.example as a template.")
        match self.config:
            case {
                "api": {"planet_api_key": str(), "orders_url": str(), 'item_type': str(), 'image_type': str()},
                "filters": {"mask": str(), 'max_cloud': float(), 'start_date': str(), 'end_date': str()},
            }:
                pass
            case ValueError as e:
                print(f'Missing or incorrect value in config.toml')
                print(str(e))
        self.API_KEY = self.config['api']['planet_api_key']
        self.ORDERS_URL = self.config['api']['orders_url']
        self.ITEM_TYPE = self.config['api']['item_type']
        self.IMAGE_TYPE = self.config['api']['image_type']
        self.auth = HTTPBasicAuth(self.API_KEY, '')
        self.mask = self.config['filters']['mask']
        self.max_cloud = self.config['filters']['max_cloud']
        self.start_date = self.config['filters']['start_date']
        self.end_date = self.config['filters']['end_date']
        
    def __repr__(self) -> str:
        return (
            f"Configuration and filters for Planet API image aquisition"
        )

# %%
my_config = PlanetConfig()
my_config.API_KEY
# Out:
# 'PLAK7f862c713f3243fb81cd6b6ce6e26f45'

# %%
##TODO
## Implement  checker to see if images have already been downloaded and skip if so
## Download thumbnails to see if image is of good quality or not, if yes download, if not add to do not download list

# %%
class PlanetImages:
    def __init__(self):
        self.config = PlanetConfig()
    
    def _load_aoi(self):
        aoi_geom = gpd.read_file(self.config.mask)
        aoi_geom = aoi_geom.to_json()
        aoi_geom = json.loads(aoi_geom)
        aoi_coords = aoi_geom['features'][0]['geometry']
        return aoi_coords
    
    def search_for_images(self):
        aoi = self._load_aoi()
        #set start and end dates
        start_date = self.config.start_date + 'T00:00:00.000Z'
        end_date = self.config.end_date + 'T00:00:00.000Z'
        #set the mask or filter for desired AOI
        geometry_filter = {
        "type": "GeometryFilter",
        "field_name": "geometry",
        "config": aoi
        }
        #set range of dates to search for
        date_range_filter = {
        "type": "DateRangeFilter",
        "field_name": "acquired",
        "config": {
            "gte": start_date,
            "lte": end_date
        }
        }

        # filter any images which are more than 10% clouds
        cloud_cover_filter = {
        "type": "RangeFilter",
        "field_name": "cloud_cover",
        "config": {
            "lte": self.config.max_cloud
        }
        }

        # create a filter that combines our geo and date filters
        # could also use an "OrFilter"
        combined_filter = {
        "type": "AndFilter",
        "config": [geometry_filter, date_range_filter, cloud_cover_filter]
        }
        #set what type of Planet scene we want to download
        # API request object
        search_request = {
        "item_types": [self.config.ITEM_TYPE], 
        "filter": combined_filter
        }
        search_result = requests.post(
            self.config.ORDERS_URL,
            auth=HTTPBasicAuth(self.config.API_KEY, ''), json=search_request)
        self.search_json = search_result.json()
        return self.search_json
    
    def get_all_avail_image_ids(self):
        #just return which images are available
        image_json = self.search_for_images()
        self.image_ids = [feature['id'] for feature in image_json['features']]
        print(f'There are {len(self.image_ids)} total images available to download.')
        return self.image_ids
    
    def get_unique_image_dates(self) -> list:
        image_json = self.search_for_images()
        self.image_list = []
        self.unique_dates = []
        #loop through all images, get unique date, and return image info/feature info
        for feature in image_json['features']:
            image_id = feature['id']
            date = image_id[0:8]
            if date not in self.unique_dates:
                self.unique_dates.append(date)
                self.image_list.append(feature)
        num_images = len(self.image_list)
        if num_images != 0:
            print(f'There are {num_images} unique image dates for download.')
            return self.image_list
        else:
            raise ValueError("Image list is empty. Try a new date, location, or filters.")

    def download_image_thumbnails(self) -> None:
        image_list = self.get_unique_image_dates()
        img_total = len(image_list)
        counter = 0
        for image in image_list:
            thumb_url = image['_links']['thumbnail']
            img_id = image['id']
            thumb_req = requests.get(thumb_url, auth=HTTPBasicAuth(self.config.API_KEY, ''))
            downloaded_thumb = glob.glob(f'data/thumbnails/{img_id}.tif')
            if not downloaded_thumb:
                print(f"Downloading image for {img_id}")
                open(f'data/thumbnails/{img_id}.tif', 'wb').write(thumb_req.content)
            else:
                pass
            # print(feature['_links']['thumbnail'])
            # counter += 1
        # return(image_list)

    def filter_images_for_quality(self) -> list:
        thumb_imgs = glob.glob("data/thumbnails/*.tif")
        good_imgs = []
        for image in thumb_imgs:
            with rio.open(image) as src:
                b, g, r, nir = src.read()
                b_mean = b.mean()
                g_mean = g.mean()
                r_mean = r.mean()
                nir_mean = nir.mean()
                # print(image, b_mean, g_mean, r_mean, nir_mean)
                if nir_mean >= 100 and r_mean < 10:
                    print(f'{image} is possibly bad and/or corrupted. Double check before downloading.')
                else:
                    good_imgs.append(image)
        return good_imgs

    def get_imgs_to_download(self, qual_cont=True):
        plan_imgs = PlanetImages()
        img_list = plan_imgs.get_unique_image_dates()
        plan_imgs.download_image_thumbnails()
        names = [os.path.basename(x) for x in glob.glob('data/thumbnails/*.tif')]
        names = [img.strip('.tif') for img in names]
        if qual_cont:
            good_imgs = plan_imgs.filter_images_for_quality()
        else:
            pass
        [i for i in img_list if i['id'] in names]

# %%
plan_imgs = PlanetImages()
# plan_imgs.get_unique_image_dates()
plan_imgs.download_image_thumbnails()
# Out:
# There are 17 unique image dates for download.

# %%
img_list = plan_imgs.get_unique_image_dates()
# Out:
# There are 17 unique image dates for download.

# %%
good_imgs = plan_imgs.filter_images_for_quality()
good_imgs = [os.path.basename(img) for img in good_imgs]
good_imgs = [img.strip('.tif') for img in good_imgs]
good_imgs

### TODO compare good_imgs with names to see which match as final imgs to downlaod
# Out:
# data/thumbnails\20190708_164141_67_1059.tif is possibly bad and/or corrupted. Double check before downloading.
# c:\Users\mattn\miniconda3\envs\gis\Lib\site-packages\rasterio\__init__.py:321: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ['20190701_204722_0f1c',
#  '20190702_151809_1020',
#  '20190703_152135_0f49',
#  '20190704_163219_0f4e',
#  '20190705_163123_1006',
#  '20190707_151825_0f4d',
#  '20190709_162920_1013',
#  '20190714_163108_0f17',
#  '20190718_165000_14_1067',
#  '20190719_163108_0f3',
#  '20190722_162912_101b',
#  '20190723_151601_1020',
#  '20190724_151544_0f2b',
#  '20190725_151708_1054',
#  '20190728_162818_1001',
#  '20190730_163301_101b']

# %%
names = [os.path.basename(x) for x in glob.glob('data/thumbnails/*.tif')]
names = [img.strip('.tif') for img in names]
names
# Out:
# ['20190701_204722_0f1c',
#  '20190702_151809_1020',
#  '20190703_152135_0f49',
#  '20190704_163219_0f4e',
#  '20190705_163123_1006',
#  '20190707_151825_0f4d',
#  '20190708_164141_67_1059',
#  '20190709_162920_1013',
#  '20190714_163108_0f17',
#  '20190718_165000_14_1067',
#  '20190719_163108_0f3',
#  '20190722_162912_101b',
#  '20190723_151601_1020',
#  '20190724_151544_0f2b',
#  '20190725_151708_1054',
#  '20190728_162818_1001',
#  '20190730_163301_101b']

# %%
[i for i in img_list if i['id'] in names]
# Out:
# [{'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190708_164141_67_1059',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190708_164141_67_1059/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190708_164141_67_1059/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.10890118691407, 41.77483165635505],
#      [-91.15308269739232, 41.623133149284506],
#      [-90.84919967833982, 41.57345086100063],
#      [-90.80462112943405, 41.72437118865252],
#      [-91.10890118691407, 41.77483165635505]]],
#    'type': 'Polygon'},
#   'id': '20190708_164141_67_1059',
#   'properties': {'acquired': '2019-07-08T16:41:41.673153Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 99,
#    'clear_percent': 100,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.9,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2.SD',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-09T08:37:02Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 101.6,
#    'satellite_id': '1059',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2508361',
#    'sun_azimuth': 130.3,
#    'sun_elevation': 63.8,
#    'updated': '2021-03-09T08:37:02Z',
#    'view_angle': 5,
#    'visible_confidence_percent': 99,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190730_163301_101b',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190730_163301_101b/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190730_163301_101b/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.1329010841148, 41.74927509308373],
#      [-91.15532597647938, 41.67588471022777],
#      [-90.85206725061204, 41.62417102219969],
#      [-90.8298016386189, 41.697784982527864],
#      [-91.1329010841148, 41.74927509308373]]],
#    'type': 'Polygon'},
#   'id': '20190730_163301_101b',
#   'properties': {'acquired': '2019-07-30T16:33:01.090511Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 92,
#    'clear_percent': 98,
#    'cloud_cover': 0.02,
#    'cloud_percent': 2,
#    'ground_control': True,
#    'gsd': 3.9,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-06T02:12:42Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 277,
#    'satellite_id': '101b',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2561598',
#    'sun_azimuth': 130.4,
#    'sun_elevation': 58.7,
#    'updated': '2021-03-06T02:12:42Z',
#    'view_angle': 3,
#    'visible_confidence_percent': 77,
#    'visible_percent': 98},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190728_162818_1001',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190728_162818_1001/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190728_162818_1001/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-90.86440684532874, 41.6887583218394],
#      [-90.88588575879845, 41.61558782911913],
#      [-90.58212089498555, 41.56563856667638],
#      [-90.56094408641377, 41.63856871433098],
#      [-90.86440684532874, 41.6887583218394]]],
#    'type': 'Polygon'},
#   'id': '20190728_162818_1001',
#   'properties': {'acquired': '2019-07-28T16:28:18.753189Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 54,
#    'clear_percent': 19,
#    'cloud_cover': 0.05,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.9,
#    'heavy_haze_percent': 5,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 76,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-06T00:51:38Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 102.2,
#    'satellite_id': '1001',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2556402',
#    'sun_azimuth': 129.3,
#    'sun_elevation': 59.1,
#    'updated': '2021-03-06T00:51:38Z',
#    'view_angle': 4,
#    'visible_confidence_percent': 54,
#    'visible_percent': 95},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190725_151708_1054',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190725_151708_1054/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190725_151708_1054/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-90.97618471252983, 41.67327637002847],
#      [-90.95757405681208, 41.606614067642774],
#      [-90.68165070548531, 41.650224007299464],
#      [-90.70053688241084, 41.716986158938354],
#      [-90.97618471252983, 41.67327637002847]]],
#    'type': 'Polygon'},
#   'id': '20190725_151708_1054',
#   'properties': {'acquired': '2019-07-25T15:17:08.706008Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 75,
#    'clear_percent': 99,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.5,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 1,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T22:15:39Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 255.7,
#    'satellite_id': '1054',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2548318',
#    'sun_azimuth': 107.5,
#    'sun_elevation': 47.3,
#    'updated': '2021-03-05T22:15:39Z',
#    'view_angle': 2,
#    'visible_confidence_percent': 59,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190724_151544_0f2b',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190724_151544_0f2b/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190724_151544_0f2b/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.12856458328827, 41.67305276515055],
#      [-91.1094781148962, 41.606450430441015],
#      [-90.83551417664894, 41.65081275545615],
#      [-90.85479341445313, 41.71718099111777],
#      [-91.12856458328827, 41.67305276515055]]],
#    'type': 'Polygon'},
#   'id': '20190724_151544_0f2b',
#   'properties': {'acquired': '2019-07-24T15:15:44.227991Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 84,
#    'clear_percent': 100,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.5,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T21:32:54Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 83.4,
#    'satellite_id': '0f2b',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2545852',
#    'sun_azimuth': 107.3,
#    'sun_elevation': 47.4,
#    'updated': '2021-03-05T21:32:54Z',
#    'view_angle': 3,
#    'visible_confidence_percent': 84,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190723_151601_1020',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190723_151601_1020/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190723_151601_1020/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-90.87989812265236, 41.733985861222244],
#      [-90.86126255104048, 41.668201886392545],
#      [-90.58914929879096, 41.711778613088434],
#      [-90.60802246244656, 41.77755499224828],
#      [-90.87989812265236, 41.733985861222244]]],
#    'type': 'Polygon'},
#   'id': '20190723_151601_1020',
#   'properties': {'acquired': '2019-07-23T15:16:01.181983Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 98,
#    'clear_percent': 100,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.5,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T20:51:56Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 184,
#    'satellite_id': '1020',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2543223',
#    'sun_azimuth': 107.1,
#    'sun_elevation': 47.6,
#    'updated': '2021-03-05T20:51:56Z',
#    'view_angle': 0,
#    'visible_confidence_percent': 98,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190722_162912_101b',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190722_162912_101b/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190722_162912_101b/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.06021291895048, 41.76743278196591],
#      [-91.08174063964842, 41.69371372559188],
#      [-90.77728949779986, 41.64411484429079],
#      [-90.75612468374486, 41.71749283297596],
#      [-91.06021291895048, 41.76743278196591]]],
#    'type': 'Polygon'},
#   'id': '20190722_162912_101b',
#   'properties': {'acquired': '2019-07-22T16:29:12.148093Z',
#    'anomalous_pixels': 0.01,
#    'clear_confidence_percent': 81,
#    'clear_percent': 89,
#    'cloud_cover': 0.09,
#    'cloud_percent': 9,
#    'ground_control': True,
#    'gsd': 3.9,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T19:45:11Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 101.5,
#    'satellite_id': '101b',
#    'shadow_percent': 1,
#    'snow_ice_percent': 0,
#    'strip_id': '2540688',
#    'sun_azimuth': 128,
#    'sun_elevation': 60.1,
#    'updated': '2021-03-05T19:45:11Z',
#    'view_angle': 5,
#    'visible_confidence_percent': 62,
#    'visible_percent': 91},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190718_165000_14_1067',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190718_165000_14_1067/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190718_165000_14_1067/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-90.96823096088875, 41.71543934493204],
#      [-90.92255141006429, 41.559505390950385],
#      [-90.60983017542715, 41.61030191375549],
#      [-90.65485828142158, 41.76688257665866],
#      [-90.96823096088875, 41.71543934493204]]],
#    'type': 'Polygon'},
#   'id': '20190718_165000_14_1067',
#   'properties': {'acquired': '2019-07-18T16:50:00.143124Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 94,
#    'clear_percent': 94,
#    'cloud_cover': 0.05,
#    'cloud_percent': 5,
#    'ground_control': True,
#    'gsd': 4,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2.SD',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T16:45:26Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'test',
#    'satellite_azimuth': 257,
#    'satellite_id': '1067',
#    'shadow_percent': 1,
#    'snow_ice_percent': 0,
#    'strip_id': '2529899',
#    'sun_azimuth': 134.3,
#    'sun_elevation': 63.3,
#    'updated': '2021-03-05T16:45:26Z',
#    'view_angle': 3.1,
#    'visible_confidence_percent': 66,
#    'visible_percent': 95},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190714_163108_0f17',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190714_163108_0f17/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190714_163108_0f17/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-90.89568887884077, 41.7259859566491],
#      [-90.91765841678574, 41.65237737027084],
#      [-90.61456656920305, 41.601802477629306],
#      [-90.59286868090769, 41.6753651087359],
#      [-90.89568887884077, 41.7259859566491]]],
#    'type': 'Polygon'},
#   'id': '20190714_163108_0f17',
#   'properties': {'acquired': '2019-07-14T16:31:08.732815Z',
#    'anomalous_pixels': 0.01,
#    'clear_confidence_percent': 91,
#    'clear_percent': 92,
#    'cloud_cover': 0.04,
#    'cloud_percent': 4,
#    'ground_control': True,
#    'gsd': 3.9,
#    'heavy_haze_percent': 1,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 3,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T14:58:32Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 107.9,
#    'satellite_id': '0f17',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2519149',
#    'sun_azimuth': 126.8,
#    'sun_elevation': 61.4,
#    'updated': '2021-03-05T14:58:32Z',
#    'view_angle': 1,
#    'visible_confidence_percent': 64,
#    'visible_percent': 96},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190709_162920_1013',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190709_162920_1013/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190709_162920_1013/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-90.92169733921567, 41.74926985759277],
#      [-90.94306541166344, 41.67708073577832],
#      [-90.64321721458855, 41.62750947886471],
#      [-90.62216020477891, 41.69956325801357],
#      [-90.92169733921567, 41.74926985759277]]],
#    'type': 'Polygon'},
#   'id': '20190709_162920_1013',
#   'properties': {'acquired': '2019-07-09T16:29:20.878972Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 91,
#    'clear_percent': 98,
#    'cloud_cover': 0.02,
#    'cloud_percent': 2,
#    'ground_control': True,
#    'gsd': 3.9,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T12:16:11Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 103.1,
#    'satellite_id': '1013',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2506980',
#    'sun_azimuth': 125.7,
#    'sun_elevation': 61.9,
#    'updated': '2021-03-05T12:16:11Z',
#    'view_angle': 3,
#    'visible_confidence_percent': 69,
#    'visible_percent': 98},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190707_151825_0f4d',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190707_151825_0f4d/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190707_151825_0f4d/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.1144065217372, 41.672589261585834],
#      [-91.0948574017264, 41.604685895867625],
#      [-90.81421647567551, 41.65034155206081],
#      [-90.83395368892842, 41.71802801640314],
#      [-91.1144065217372, 41.672589261585834]]],
#    'type': 'Polygon'},
#   'id': '20190707_151825_0f4d',
#   'properties': {'acquired': '2019-07-07T15:18:25.147254Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 98,
#    'clear_percent': 100,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.6,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T11:04:38Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 84.5,
#    'satellite_id': '0f4d',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2502596',
#    'sun_azimuth': 105,
#    'sun_elevation': 50,
#    'updated': '2021-03-05T11:04:38Z',
#    'view_angle': 3,
#    'visible_confidence_percent': 77,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190705_163123_1006',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190705_163123_1006/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190705_163123_1006/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.14883842522032, 41.78968449494403],
#      [-91.17063432234647, 41.717748461524934],
#      [-90.87406647411456, 41.66765969669081],
#      [-90.85255197662302, 41.73959536270637],
#      [-91.14883842522032, 41.78968449494403]]],
#    'type': 'Polygon'},
#   'id': '20190705_163123_1006',
#   'properties': {'acquired': '2019-07-05T16:31:23.245382Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 96,
#    'clear_percent': 100,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.8,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T09:46:55Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 182,
#    'satellite_id': '1006',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2498680',
#    'sun_azimuth': 125.4,
#    'sun_elevation': 62.2,
#    'updated': '2021-03-05T09:46:55Z',
#    'view_angle': 0,
#    'visible_confidence_percent': 72,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190704_163219_0f4e',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190704_163219_0f4e/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190704_163219_0f4e/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.01572827275605, 41.763499904032955],
#      [-91.03775051116173, 41.690903897338664],
#      [-90.73831746511244, 41.64020152941476],
#      [-90.71651831493263, 41.712908778000035],
#      [-91.01572827275605, 41.763499904032955]]],
#    'type': 'Polygon'},
#   'id': '20190704_163219_0f4e',
#   'properties': {'acquired': '2019-07-04T16:32:19.776062Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 99,
#    'clear_percent': 100,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.9,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T08:58:11Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 270,
#    'satellite_id': '0f4e',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2496744',
#    'sun_azimuth': 126,
#    'sun_elevation': 62.4,
#    'updated': '2021-03-05T08:58:11Z',
#    'view_angle': 2.2,
#    'visible_confidence_percent': 99,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190703_152135_0f49',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190703_152135_0f49/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190703_152135_0f49/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.15610361117398, 41.68770905503531],
#      [-91.13764173124844, 41.620156535007844],
#      [-90.8571079216303, 41.6634918268308],
#      [-90.87590335475275, 41.73125569981158],
#      [-91.15610361117398, 41.68770905503531]]],
#    'type': 'Polygon'},
#   'id': '20190703_152135_0f49',
#   'properties': {'acquired': '2019-07-03T15:21:35.116006Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 98,
#    'clear_percent': 100,
#    'cloud_cover': 0,
#    'cloud_percent': 0,
#    'ground_control': True,
#    'gsd': 3.6,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T08:05:28Z',
#    'publishing_stage': 'finalized',
#    'quality_category': 'standard',
#    'satellite_azimuth': 258.4,
#    'satellite_id': '0f49',
#    'shadow_percent': 0,
#    'snow_ice_percent': 0,
#    'strip_id': '2494819',
#    'sun_azimuth': 104.8,
#    'sun_elevation': 50.4,
#    'updated': '2021-03-05T08:05:28Z',
#    'view_angle': 4,
#    'visible_confidence_percent': 98,
#    'visible_percent': 100},
#   'type': 'Feature'},
#  {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190702_151809_1020',
#    'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190702_151809_1020/assets/',
#    'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190702_151809_1020/thumb'},
#   '_permissions': ['assets.basic_analytic_4b:download',
#    'assets.basic_analytic_4b_rpc:download',
#    'assets.basic_analytic_4b_xml:download',
#    'assets.basic_udm2:download',
#    'assets.ortho_analytic_3b:download',
#    'assets.ortho_analytic_3b_xml:download',
#    'assets.ortho_analytic_4b:download',
#    'assets.ortho_analytic_4b_sr:download',
#    'assets.ortho_analytic_4b_xml:download',
#    'assets.ortho_udm2:download',
#    'assets.ortho_visual:download'],
#   'assets': ['basic_analytic_4b',
#    'basic_analytic_4b_rpc',
#    'basic_analytic_4b_xml',
#    'basic_udm2',
#    'ortho_analytic_3b',
#    'ortho_analytic_3b_xml',
#    'ortho_analytic_4b',
#    'ortho_analytic_4b_sr',
#    'ortho_analytic_4b_xml',
#    'ortho_udm2',
#    'ortho_visual'],
#   'geometry': {'coordinates': [[[-91.08427313229951, 41.681895473179054],
#      [-91.064678064003, 41.61445410880774],
#      [-90.78522593207533, 41.66041638470193],
#      [-90.80504193039812, 41.72751510795389],
#      [-91.08427313229951, 41.681895473179054]]],
#    'type': 'Polygon'},
#   'id': '20190702_151809_1020',
#   'properties': {'acquired': '2019-07-02T15:18:09.41267Z',
#    'anomalous_pixels': 0,
#    'clear_confidence_percent': 97,
#    'clear_percent': 99,
#    'cloud_cover': 0.01,
#    'cloud_percent': 1,
#    'ground_control': True,
#    'gsd': 3.6,
#    'heavy_haze_percent': 0,
#    'instrument': 'PS2',
#    'item_type': 'PSScene',
#    'light_haze_percent': 0,
#    'pixel_resolution': 3,
#    'provider': 'planetscope',
#    'published': '2021-03-05T07:06:33Z',
 'pixel_resolution': 3, 'provider': 'planetscope', 'published': '2021-03-05T07:06:33Z', 'publishing_stage': 'finalized', 'quality_category': 'standard', 'satellite_azimuth': 82.4, 'satellite_id': '1020', 'shadow_percent': 0, 'snow_ice_percent': 0, 'strip_id': '2492635', 'sun_azimuth': 104.9, 'sun_elevation': 50.5, 'updated': '2021-03-05T07:06:33Z', 'view_angle': 5, 'visible_confidence_percent': 76, 'visible_percent': 99}, 'type': 'Feature'}
# {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190701_204722_0f1c', 'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190701_204722_0f1c/assets/', 'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190701_204722_0f1c/thumb'}, '_permissions': ['assets.basic_udm2:download', 'assets.ortho_udm2:download', 'assets.ortho_visual:download'], 'assets': ['basic_udm2', 'ortho_udm2', 'ortho_visual'], 'geometry': {'coordinates': [[[-90.82469353877565, 41.6504766346342], [-90.83202542885046, 41.69804972929871], [-91.02786187552897, 41.680496346739936], [-91.02001592289014, 41.6329645179102], [-90.82469353877565, 41.6504766346342]]], 'type': 'Polygon'}, 'id': '20190701_204722_0f1c', 'properties': {'acquired': '2019-07-01T20:47:22.358216Z', 'anomalous_pixels': 0, 'cloud_cover': 0.04, 'ground_control': True, 'gsd': 2.5, 'instrument': 'PS2', 'item_type': 'PSScene', 'pixel_resolution': 3, 'provider': 'planetscope', 'published': '2021-03-05T06:09:37Z', 'publishing_stage': 'finalized', 'quality_category': 'standard', 'satellite_azimuth': 168.7, 'satellite_id': '0f1c', 'strip_id': '2491429', 'sun_azimuth': 253.4, 'sun_elevation': 52, 'updated': '2021-03-05T06:09:37Z', 'view_angle': 0}, 'type': 'Feature'}

# %%
type(good_imgs)
# Out:
# list

# %%
imgs_to_download = []
for i in img_list:
    if i['id'] in good_imgs:
        imgs_to_download.append(i)
# Out:
# 20190708_164141_67_1059
# 20190730_163301_101b
# 20190728_162818_1001
# 20190725_151708_1054
# 20190724_151544_0f2b
# 20190723_151601_1020
# 20190722_162912_101b
# 20190719_163108_0f3f
# 20190718_165000_14_1067
# 20190714_163108_0f17
# 20190709_162920_1013
# 20190707_151825_0f4d
# 20190705_163123_1006
# 20190704_163219_0f4e
# 20190703_152135_0f49
# 20190702_151809_1020
# 20190701_204722_0f1c

# %%
imgs_to_download
# Out:
# []

# %%
thumb_imgs = glob.glob("data/thumbnails/*.tif")
for image in thumb_imgs:
    with rio.open(image) as src:
        b, g, r, nir = src.read()
        b_mean = b.mean()
        g_mean = g.mean()
        r_mean = r.mean()
        nir_mean = nir.mean()
        print(image, b_mean, g_mean, r_mean, nir_mean)
# Out:
# data/thumbnails\20190701_204722_0f1c_thumbnail.tif 48.8843994140625 44.47148132324219 36.7052001953125 79.41123962402344
# data/thumbnails\20190702_151809_1020_thumbnail.tif 46.22706604003906 41.96473693847656 34.938201904296875 77.29454040527344
# data/thumbnails\20190703_152135_0f49_thumbnail.tif 38.10209655761719 35.028656005859375 27.7052001953125 77.23617553710938
# data/thumbnails\20190704_163219_0f4e_thumbnail.tif 35.159637451171875 31.262435913085938 23.499710083007812 77.74200439453125
# data/thumbnails\20190705_163123_1006_thumbnail.tif 48.339874267578125 44.24713134765625 36.20344543457031 77.77702331542969
# data/thumbnails\20190707_151825_0f4d_thumbnail.tif 43.09149169921875 40.491790771484375 33.87896728515625 76.90933227539062
# data/thumbnails\20190708_164141_67_1059_thumbnail.tif 41.12861633300781 13.400466918945312 2.908905029296875 136.1652374267578
# data/thumbnails\20190709_162920_1013_thumbnail.tif 51.93658447265625 49.27268981933594 42.94865417480469 76.95213317871094
# data/thumbnails\20190714_163108_0f17_thumbnail.tif 37.91905212402344 36.22752380371094 28.278793334960938 77.55134582519531
# data/thumbnails\20190718_165000_14_1067_thumbnail.tif 61.42237854003906 61.66499328613281 47.80644226074219 136.46873474121094
# data/thumbnails\20190719_163108_0f3f_thumbnail.tif 31.421401977539062 29.715621948242188 20.488174438476562 77.17391967773438
# data/thumbnails\20190722_162912_101b_thumbnail.tif 37.66209411621094 37.54405212402344 31.546173095703125 77.42294311523438
# data/thumbnails\20190723_151601_1020_thumbnail.tif 30.219528198242188 30.43768310546875 24.569351196289062 76.64474487304688
# data/thumbnails\20190724_151544_0f2b_thumbnail.tif 30.297378540039062 31.275039672851562 24.19110107421875 77.39181518554688
# data/thumbnails\20190725_151708_1054_thumbnail.tif 26.803176879882812 27.510910034179688 18.610855102539062 77.18170166015625
# data/thumbnails\20190728_162818_1001_thumbnail.tif 41.68519592285156 40.17608642578125 34.43243408203125 77.06497192382812
# data/thumbnails\20190730_163301_101b_thumbnail.tif 26.880355834960938 26.670791625976562 19.916748046875 77.5396728515625

# %%
img0 = plan_images['features']
for x in img0:
    keys = x.keys()
    print(keys)

# %%
def check_images_for_quality(planet_obj : PlanetImages):
    search_result = planet_obj.search_for_images()
    unique_imgs = planet_obj.get_unique_image_dates()
    counter = 0
    for i in unique_imgs:
        counter +=1
        features = search_result['features'][counter]
        features = search_result['features'][3]

# %%
counter = 0
for feature in search_result['features']:
    print(feature['_links']['thumbnail'])
    counter += 1
print(counter)
# Out:
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190708_164141_67_1059/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190730_163301_101b/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190730_163300_101b/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190728_162818_1001/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190728_151633_0f4d/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190728_151634_0f4d/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190725_151708_1054/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190725_151709_1054/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190725_163127_1044/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190724_151544_0f2b/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190724_163109_1025/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190723_151601_1020/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190723_162933_1008/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190722_162912_101b/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190722_151606_0f36/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190722_151607_0f36/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190719_163108_0f3f/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190718_165000_14_1067/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190714_163108_0f17/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190709_162920_1013/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190708_152003_0f2d/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190707_151825_0f4d/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190707_163344_1105/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190705_163123_1006/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190705_162829_1004/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190705_162830_1004/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190704_163219_0f4e/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190703_152135_0f49/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190702_151809_1020/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190701_204722_0f1c/thumb
# https://tiles.planet.com/data/v1/item-types/PSScene/items/20190701_204721_1_0f1c/thumb
# 31

# %%
id_test = search_result['features'][2]['id']
id_test
# Out:
# '20190730_163300_101b'

# %%
thumb_url = search_result['features'][2]['_links']['thumbnail']
# thumb_url = f'https://tiles.planet.com/data/v1/item-types/{my_config.ITEM_TYPE}/items/{siever_images[0]}/thumb'
result = \
  requests.get(
    thumb_url,
    auth=HTTPBasicAuth(my_config.API_KEY, '')
  )
open(f'data/thumbnail_test.tif', 'wb').write(result.content)

# %%
siever_images = plan_imgs.get_unique_image_dates()
# siever_images = plan_imgs.get_avail_image_ids()
siever_images
# Out:
# There are 17 unique dates for image download.
# ['20190708_164141_67_1059',
#  '20190730_163301_101b',
#  '20190728_162818_1001',
#  '20190725_151708_1054',
#  '20190724_151544_0f2b',
#  '20190723_151601_1020',
#  '20190722_162912_101b',
#  '20190719_163108_0f3f',
#  '20190718_165000_14_1067',
#  '20190714_163108_0f17',
#  '20190709_162920_1013',
#  '20190707_151825_0f4d',
#  '20190705_163123_1006',
#  '20190704_163219_0f4e',
#  '20190703_152135_0f49',
#  '20190702_151809_1020',
#  '20190701_204722_0f1c']

# %%
tarfeature = search_result['features'][3]
tarfeature
# Out:
# {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190728_162818_1001',
#   'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20190728_162818_1001/assets/',
#   'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20190728_162818_1001/thumb'},
#  '_permissions': ['assets.basic_analytic_4b:download',
#   'assets.basic_analytic_4b_rpc:download',
#   'assets.basic_analytic_4b_xml:download',
#   'assets.basic_udm2:download',
#   'assets.ortho_analytic_3b:download',
#   'assets.ortho_analytic_3b_xml:download',
#   'assets.ortho_analytic_4b:download',
#   'assets.ortho_analytic_4b_sr:download',
#   'assets.ortho_analytic_4b_xml:download',
#   'assets.ortho_udm2:download',
#   'assets.ortho_visual:download'],
#  'assets': ['basic_analytic_4b',
#   'basic_analytic_4b_rpc',
#   'basic_analytic_4b_xml',
#   'basic_udm2',
#   'ortho_analytic_3b',
#   'ortho_analytic_3b_xml',
#   'ortho_analytic_4b',
#   'ortho_analytic_4b_sr',
#   'ortho_analytic_4b_xml',
#   'ortho_udm2',
#   'ortho_visual'],
#  'geometry': {'coordinates': [[[-90.86440684532874, 41.6887583218394],
#     [-90.88588575879845, 41.61558782911913],
#     [-90.58212089498555, 41.56563856667638],
#     [-90.56094408641377, 41.63856871433098],
#     [-90.86440684532874, 41.6887583218394]]],
#   'type': 'Polygon'},
#  'id': '20190728_162818_1001',
#  'properties': {'acquired': '2019-07-28T16:28:18.753189Z',
#   'anomalous_pixels': 0,
#   'clear_confidence_percent': 54,
#   'clear_percent': 19,
#   'cloud_cover': 0.05,
#   'cloud_percent': 0,
#   'ground_control': True,
#   'gsd': 3.9,
#   'heavy_haze_percent': 5,
#   'instrument': 'PS2',
#   'item_type': 'PSScene',
#   'light_haze_percent': 76,
#   'pixel_resolution': 3,
#   'provider': 'planetscope',
#   'published': '2021-03-06T00:51:38Z',
#   'publishing_stage': 'finalized',
#   'quality_category': 'standard',
#   'satellite_azimuth': 102.2,
#   'satellite_id': '1001',
#   'shadow_percent': 0,
#   'snow_ice_percent': 0,
#   'strip_id': '2556402',
#   'sun_azimuth': 129.3,
#   'sun_elevation': 59.1,
#   'updated': '2021-03-06T00:51:38Z',
#   'view_angle': 4,
#   'visible_confidence_percent': 54,
#   'visible_percent': 95},
#  'type': 'Feature'}

# %%
thumb_url = search_result['features'][2]['_links']['thumbnail']
# thumb_url = f'https://tiles.planet.com/data/v1/item-types/{my_config.ITEM_TYPE}/items/{siever_images[0]}/thumb'
result = \
  requests.get(
    thumb_url,
    auth=HTTPBasicAuth(my_config.API_KEY, '')
  )
open(f'data/thumbnail_test.tif', 'wb').write(result.content)
# Out:
# 47821

# %%
for i in siever_images:
    id0_url = f'https://api.planet.com/data/v1/item-types/{my_config.ITEM_TYPE}/items/{i}/assets'

    # Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
    result = \
    requests.get(
        id0_url,
        auth=HTTPBasicAuth(my_config.API_KEY, '')
    )

    # List of asset types available for this particular satellite image
    print(result.json().keys())

# %%
# thumb_url = f'https://tiles.planet.com/data/v1/item-types/{my_config.ITEM_TYPE}/items/{siever_images[0]}/thumb'
# result = \
#   requests.get(
#     thumb_url,
#     auth=HTTPBasicAuth(my_config.API_KEY, '')
#   )
# open(f'data/thumbnail_{siever_images[0]}.tif', 'wb').write(result.content)
# Out:
# <Response [200]>

# %%
# download one of the images
id0 = image_ids[9]
id0_url = f'https://api.planet.com/data/v1/item-types/{my_config.ITEM_TYPE}/items/{i}/assets'

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(API_KEY, '')
  )

# List of asset types available for this particular satellite image
print(result.json().keys())
# Out:
# dict_keys(['basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_udm2', 'ortho_analytic_4b', 'ortho_analytic_4b_sr', 'ortho_analytic_4b_xml', 'ortho_udm2', 'ortho_visual'])

# %%
#check if the image type we want is active or not
print(result.json()['ortho_analytic_4b_sr']['status'])
# Out:
# inactive

# %%
#activate if not activated
# Parse out useful links
links = result.json()[u"ortho_analytic_4b_sr"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'analytic' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(API_KEY, '')
  )

# %%
# check status
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(API_KEY, '')
  )
    
print(activation_status_result.json()["status"])
# Out:
# active

# %%
# check to see if product is active or not
num_loops = 20
count = 0
while(count < num_loops):
    count += 1
    activation_status_result = \
        requests.get(
            self_link,
            auth=HTTPBasicAuth(API_KEY, '')
        )
    img_status = activation_status_result.json()["status"]    
    print(img_status)
    success_states = ['active']
    if activation_status_result == 'failed':
        raise Exception()
    elif img_status in success_states:
        break
    
    time.sleep(10)
# Out:
# activating
# activating
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Dev\Planet-LTSM\planet-api.ipynb Cell 23 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/d%3A/Dev/Planet-LTSM/planet-api.ipynb#X25sZmlsZQ%3D%3D?line=15'>16</a> elif img_status in success_states:
#      <a href='vscode-notebook-cell:/d%3A/Dev/Planet-LTSM/planet-api.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a>     break
# ---> <a href='vscode-notebook-cell:/d%3A/Dev/Planet-LTSM/planet-api.ipynb#X25sZmlsZQ%3D%3D?line=18'>19</a> time.sleep(10)
#
# KeyboardInterrupt:

# %%
##TODO Add a check to see if image is already downloaded and skip if so.

# %%
# Image can be downloaded by making a GET with your Planet API key, from here:
download_link = activation_status_result.json()["location"]
print(download_link)
# download the image
dwnl_image = requests.get(download_link)
# and save it
open(f'data/accola/dwnl_image_{id0}.tif', 'wb').write(dwnl_image.content)
# Out:
# https://api.planet.com/data/v1/download?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..Aj0CB9D8Hx_h5oZfFGxMoqqxMPDQR0dypPz-qMAqxHquJ3DgsudSd7XNbtTWoFNoOrVdIvvCz_BmKJabRt0dZQ
# 327245340

# %%
# # create an api request from the search specifications
# def build_request(aoi_geom, start_date, stop_date):
#     '''build a data api search request for clear PSScene 4-Band imagery'''
#     item_type = 'PSScene'
#     query = filters.and_filter(
#         filters.geom_filter(aoi_geom),
#         filters.range_filter('clear_percent', gte=90),
#         filters.date_range('acquired', gt=start_date),
#         filters.date_range('acquired', lt=stop_date)
#     )
#     return filters.build_search_request(query, ['PSScene'])

# %%
request = build_request(aoi_coords, start_date, stop_date)
request

# %%
# search the data api
def search_data_api(request, client, limit=500):
    result = client.quick_search(request)
    
    # this returns a generator
    return result.items_iter(limit=limit)

items = list(search_data_api(request, client))
print(len(items))

# %%
test_items = items[:2]
# filter to item ids
ids = [i['id'] for i in test_items]
ids

# %%
name = 'tutorial_order'
item_type = 'PSScene'
# 'analytic_sr_udm2' is the basic surface reflectance corrected image, 4 bands
bundle = 'analytic_sr_udm2'
# and the 8 band version
# bundle = 'analytic_8b_sr_udm2'
clip_tool = {'clip': {'aoi': aoi_coords}}
# # example of a bandmath tool to calculate NDVI that will overwrite default bands
# bandmath_tool = {'bandmath': {
#     "pixel_type": "32R",
#     "b1": "(b4 - b3) / (b4+b3)",
#     "b2": "(b4 / b2) - 1",
# }}

# tools = [clip_tool, bandmath_tool]
tools = clip_tool

orders_request = {
    'name': name,
    'products': [{
        'item_ids': ids,
        'item_type': item_type,
        'product_bundle': bundle
    }],
    'tools': tools,
    'delivery': {
        'single_archive': True,
        'archive_filename':'{{name}}_{{order_id}}.zip',
        'archive_type':'zip'
    },
        'notifications': {
                   'email': False
    },
}

# pprint(orders_request, indent=1)

# %%
order_info = client.create_order(orders_request).get()

order_id = order_info['id']
order_id

# %%
order_info['_links']['_self']

# %%
def poll_for_success(order_id, client, num_loops=50) -> None:
    count = 0
    while(count < num_loops):
        count += 1
        order_info = client.get_individual_order(order_id).get()
        state = order_info['state']
        print(state)
        success_states = ['success', 'partial']
        if state == 'failed':
            raise Exception(response)
        elif state in success_states:
            break
        
        time.sleep(30)
        
poll_for_success(order_id, client)

# %%
demo_data_dir = os.path.join('data', 'demo')
# make the download directory if it doesn't exist
Path(demo_data_dir).mkdir(parents=True, exist_ok=True)

# %%
orders_url = order_info['_links']['_self']

# %%
def download_order(order_url, auth, overwrite=False):
    r = requests.get(order_url, auth=auth)
    print(r)

    response = r.json()
    results = response['_links']['results']
    results_urls = [r['location'] for r in results]
    results_names = [r['name'] for r in results]
    results_paths = [pathlib.Path(os.path.join('data', n)) for n in results_names]
    print('{} items to download'.format(len(results_urls)))
    
    for url, name, path in zip(results_urls, results_names, results_paths):
        if overwrite or not path.exists():
            print('downloading {} to {}'.format(name, path))
            r = requests.get(url, allow_redirects=True)
            path.parent.mkdir(parents=True, exist_ok=True)
            open(path, 'wb').write(r.content)
        else:
            print('{} already exists, skipping {}'.format(path, name))
            
    return dict(zip(results_names, results_paths))

# %%
# %system planet orders download 4fc4e8f9-58e4-4521-966d-56a34ee41797
